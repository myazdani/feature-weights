# %%
import pandas as pd
from pylab import *
import cv2

# %matplotlib inline

# %%
df = pd.read_csv("../../data/images/features/CUB/BVLCref_fc8-CUB.csv")

# %%
df.head()
# Out:
#                                           Unnamed: 0     fc8.0     fc8.1  \
# 0  ../data/CUB/059.California_Gull/California_Gul... -0.712353 -0.427479
# 1  ../data/CUB/059.California_Gull/California_Gul...  0.698500 -3.910873
# 2  ../data/CUB/059.California_Gull/California_Gul... -2.511306 -0.356434
# 3  ../data/CUB/059.California_Gull/California_Gul... -0.751069  1.361277
# 4  ../data/CUB/059.California_Gull/California_Gul... -0.429602 -2.057926
#
#       fc8.2     fc8.3     fc8.4     fc8.5     fc8.6      fc8.7      fc8.8  \
# 0  4.746050  3.712373  8.109741  0.952750  3.805638   2.380459   3.543605
# 1  9.680934  5.434350  6.112871  3.700256  7.632246   5.248984   9.663090
# 2  3.859857  1.366481  3.984537  0.317946  2.371047   8.389423  11.444900
# 3  6.313211  2.730820  6.373077  2.548513  2.697871  10.106471  11.475080
# 4  3.801352  3.188107  3.720882  3.825815  5.468174   0.974308   2.156410
#
#      ...      fc8.990   fc8.991   fc8.992   fc8.993   fc8.994   fc8.995  \
# 0    ...    -2.517011  2.628215 -0.169125 -2.614629 -0.294936  0.953678
# 1    ...    -3.777849  0.211898 -2.003361  2.024098  1.495889  4.724365
# 2    ...    -3.470995  1.073291 -0.616502 -1.802221  1.321991  3.769702
# 3    ...    -3.405309  1.666743  0.949258 -0.528782  2.903914  2.637055
# 4    ...    -1.095180  0.969332 -1.300717 -0.583457  2.682113  1.594816
#
#     fc8.996   fc8.997   fc8.998   fc8.999
# 0 -0.974437 -0.987871 -1.185797  2.643212
# 1 -2.026182  1.607347 -1.374238  0.124584
# 2 -0.542082 -1.501365 -0.364977  2.707583
# 3 -0.475946  0.672456  0.556350  2.254046
# 4 -1.056411  0.413581  1.430080 -0.161666
#
# [5 rows x 1001 columns]

# %%
df.shape
# Out:
# (6033, 1001)

# %%
img_paths = list(df.iloc[:,0])

# %%
img_paths = ["../../data/images/imgs/" + img_path.split("data/")[-1] for img_path in img_paths]

# %%
img = cv2.imread(img_paths[4])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(img)
